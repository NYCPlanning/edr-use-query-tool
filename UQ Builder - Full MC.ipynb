# %%
import pandas as pd
from pathlib import Path

# %%
RESOURCES_DIRECTORY = Path("./resources")
OUTPUT_DIRECTORY = Path("./output")
OUTPUT_DIRECTORY.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Clean use groups exported from Excel

# %% [markdown]
# ### Sample set (UGX only)

# %%
use_groups = pd.read_csv(RESOURCES_DIRECTORY / "use_groups.csv")
use_groups
# Out:
#    Use Group                                       Uses Header  \
# 0          X                          Food Manufacturing (311)
# 1          X                          Food Manufacturing (311)
# 2          X                          Food Manufacturing (311)
# 3          X                          Food Manufacturing (311)
# 4          X                          Food Manufacturing (311)
# 5          X                          Food Manufacturing (311)
# 6          X  Beverage and Tobacco Product Manufacturing (312)
# 7          X  Beverage and Tobacco Product Manufacturing (312)
# 8          X  Beverage and Tobacco Product Manufacturing (312)
# 9        NaN                                               NaN
# 10       NaN                                               NaN
# 11       NaN                                               NaN
# 12       NaN                                               NaN
# 13       NaN                                               NaN
# ...

# %%
use_groups_cleaned = (
    use_groups.replace({r"\s+$": "", r"^\s+": ""}, regex=True)
    .replace(r"\n", "", regex=True)
    .dropna()
)
use_groups_cleaned
# Out:
#   Use Group                                       Uses Header  \
# 0         X                          Food Manufacturing (311)
# 1         X                          Food Manufacturing (311)
# 2         X                          Food Manufacturing (311)
# 3         X                          Food Manufacturing (311)
# 4         X                          Food Manufacturing (311)
# 5         X                          Food Manufacturing (311)
# 6         X  Beverage and Tobacco Product Manufacturing (312)
# 7         X  Beverage and Tobacco Product Manufacturing (312)
# 8         X  Beverage and Tobacco Product Manufacturing (312)
#
#                                    Uses (NAICS Code) R1 R2 R3 R4 R5 R6 R7  \
# 0                   Animal food manufacturing (3111)  –  –  –  –  –  –  –
# 1                        Sugar manufacturing (31131)  –  –  –  –  –  –  –
# 2  All other sugar and confectionary product manu...  –  –  –  –  –  –  –
# ...

# %%
naics_description_columns = ["Uses Header", "Uses (NAICS Code)"]
other_columns = [
    col for col in use_groups_cleaned if col not in naics_description_columns
]

use_groups_cleaned[other_columns] = use_groups_cleaned[other_columns].applymap(
    lambda x: x.replace(" ", "").strip()
)
use_groups_cleaned
# Out:
# C:\Users\m_carper\AppData\Local\Temp\ipykernel_18572\2938425609.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   use_groups_cleaned[other_columns] = use_groups_cleaned[other_columns].applymap(
#   Use Group                                       Uses Header  \
# 0         X                          Food Manufacturing (311)
# 1         X                          Food Manufacturing (311)
# 2         X                          Food Manufacturing (311)
# 3         X                          Food Manufacturing (311)
# 4         X                          Food Manufacturing (311)
# 5         X                          Food Manufacturing (311)
# 6         X  Beverage and Tobacco Product Manufacturing (312)
# 7         X  Beverage and Tobacco Product Manufacturing (312)
# 8         X  Beverage and Tobacco Product Manufacturing (312)
#
#                                    Uses (NAICS Code) R1 R2 R3 R4 R5 R6 R7  \
# ...

# %%
use_groups_cleaned.to_csv(OUTPUT_DIRECTORY / "use_groups_cleaned.csv", index=False)

# %% [markdown]
# ### Full set (all UGs)

# %%
ug_all = pd.read_excel('C:/Users/m_carper/OneDrive - NYC O365 HOSTED/Use Group Chart - Transposed All UGs.xlsx')
ug_all
# Out:
#     Use Group                                         Use Header  \
# 0           I                                        Agriculture
# 1           I                                          Open Uses
# 2           I                                          Open Uses
# 3           I                                          Open Uses
# 4           I                                          Open Uses
# ..        ...                                                ...
# 239         X  Electrical Equipment, Appliance, and Component...
# 240         X       Transportation Equipment Manufacturing (336)
# 241         X  Furniture and Related Product Manufacturing (3...
# 242         X                 Miscellaneous Manufacturing (339)
# 243         X                 Miscellaneous Manufacturing (339)
#
#                                          Use Name Full  \
# 0    Agricultural #uses#, including greenhouses, nu...
# 1                                           Cemeteries
# ...

# %%
ug_cleaned = (
    ug_all.replace({r"\s+$": "", r"^\s+": ""}, regex=True)
    .replace(r"\n", "", regex=True)
)

naics_columns = ["Use Name Full", "Use NAICS Code", "NAICS Notes"]

other_columns = [
    col for col in ug_cleaned if col not in naics_columns
]

ug_cleaned = ug_cleaned[other_columns]
ug_cleaned
# Out:
#     Use Group                                         Use Header  \
# 0           I                                        Agriculture
# 1           I                                          Open Uses
# 2           I                                          Open Uses
# 3           I                                          Open Uses
# 4           I                                          Open Uses
# ..        ...                                                ...
# 239         X  Electrical Equipment, Appliance, and Component...
# 240         X       Transportation Equipment Manufacturing (336)
# 241         X  Furniture and Related Product Manufacturing (337)
# 242         X                  Miscellaneous Manufacturing (339)
# 243         X                  Miscellaneous Manufacturing (339)
#
#                                               Use Name  R1  R2  R3  R4  R5  \
# 0    Agricultural #uses#, including greenhouses, nu...  ●P  ●P  ●P  ●P  ●P
# ...

# %% [markdown]
# ## Pivot use group zoning district columns

# %%
# id_columns = ["Use Group", "Uses Header", "Uses (NAICS Code)"]
# use_groups_zoning_districts = ug_cleaned.melt(
#     id_vars=id_columns, var_name="Zoning District", value_name="Permitted Value"
# )
# use_groups_zoning_districts

# %%
id_columns = ["Use Group", "Use Header", "Use Name"]

use_groups_zoning_districts = ug_cleaned.melt(
    id_vars=id_columns, var_name="Zoning District", value_name="Permitted Value"
)

use_groups_zoning_districts
# Out:
#      Use Group                                         Use Header  \
# 0            I                                        Agriculture
# 1            I                                          Open Uses
# 2            I                                          Open Uses
# 3            I                                          Open Uses
# 4            I                                          Open Uses
# ...        ...                                                ...
# 5119         X  Electrical Equipment, Appliance, and Component...
# 5120         X       Transportation Equipment Manufacturing (336)
# 5121         X  Furniture and Related Product Manufacturing (337)
# 5122         X                  Miscellaneous Manufacturing (339)
# 5123         X                  Miscellaneous Manufacturing (339)
#
#                                                Use Name Zoning District  \
# 0     Agricultural #uses#, including greenhouses, nu...              R1
# ...

# %%
use_groups_zoning_districts.to_csv(
    OUTPUT_DIRECTORY / "use_groups_zoning_districts_full.csv", index=False
)

# %% [markdown]
# ## Parse use group zoning district values

# %%
use_groups_zoning_districts["Permitted Value"].value_counts()
# Out:
# Permitted Value
# –                 2587
# ●                 1055
# ●P                 435
# ○                  342
# ●S     P           183
# ●U                 175
# ●P     U           128
# ●S                 110
# ●S     U            35
# ♦                   24
# ●S     P     U      16
# ♦P                  12
# ♦P     U            10
# *                    9
# ♦S                   2
# ●S    U              1
# Name: count, dtype: int64

# %%
def parse_naics_text(naics_text: str) -> str:
    return naics_text.split("(")[1].removesuffix(")").replace("in", "").strip()

# %%
# use_groups_zoning_districts["NAICS Code"] = use_groups_zoning_districts[
#     ["Uses (NAICS Code)"]
# ].map(parse_naics_text)
# use_groups_zoning_districts

# %%
PERMITTED_KEY = {
    "–": "Not permitted",
    "●": "Permitted",
    "♦": "Permitted with limitations",
    "*": "Permitted with limitations",
    "○": "Special permit required",
    "S": "Size restriction",
    "P": "Additional conditions",
    "U": "Open use allowances",
}
PERMITTED_VALUE_COLUMNS = list(PERMITTED_KEY.values())

# %%
def parse_permitted_value(row: pd.Series) -> list:
    for character in PERMITTED_KEY.keys():
        if character in row["Permitted Value"]:
            row[PERMITTED_KEY[character]] = True
        else:
            row[PERMITTED_KEY[character]] = False
    return row

# %%
def parse_permitted_value(row: pd.Series) -> list:
    for character in PERMITTED_KEY.keys():
        if character in row["Permitted Value"]:
            row[PERMITTED_KEY[character]] = True
        else:
            row[PERMITTED_KEY[character]] = False
    return row

# %%
use_groups_zoning_districts = use_groups_zoning_districts.reindex(
    columns=[
        "Use Group",
        "Use Header",
        "Use Name",
#         "Uses (NAICS Code)",
#         "NAICS Code",
        "Zoning District",
        "Permitted Value",
    ]
    + PERMITTED_VALUE_COLUMNS
)
use_groups_zoning_districts
# Out:
#      Use Group                                         Use Header  \
# 0            I                                        Agriculture
# 1            I                                          Open Uses
# 2            I                                          Open Uses
# 3            I                                          Open Uses
# 4            I                                          Open Uses
# ...        ...                                                ...
# 5119         X  Electrical Equipment, Appliance, and Component...
# 5120         X       Transportation Equipment Manufacturing (336)
# 5121         X  Furniture and Related Product Manufacturing (337)
# 5122         X                  Miscellaneous Manufacturing (339)
# 5123         X                  Miscellaneous Manufacturing (339)
#
#                                                Use Name Zoning District  \
# 0     Agricultural #uses#, including greenhouses, nu...              R1
# ...

# %%
use_groups_zoning_districts_flags = use_groups_zoning_districts.apply(parse_permitted_value, axis=1)
use_groups_zoning_districts_flags
# Out:
#      Use Group                                         Use Header  \
# 0            I                                        Agriculture
# 1            I                                          Open Uses
# 2            I                                          Open Uses
# 3            I                                          Open Uses
# 4            I                                          Open Uses
# ...        ...                                                ...
# 5119         X  Electrical Equipment, Appliance, and Component...
# 5120         X       Transportation Equipment Manufacturing (336)
# 5121         X  Furniture and Related Product Manufacturing (337)
# 5122         X                  Miscellaneous Manufacturing (339)
# 5123         X                  Miscellaneous Manufacturing (339)
#
#                                                Use Name Zoning District  \
# 0     Agricultural #uses#, including greenhouses, nu...              R1
# ...

# %%
use_groups_zoning_districts_flags["Is Allowed"] = use_groups_zoning_districts_flags.apply(lambda row: "No" if row["Not permitted"] else ("Yes*" if row[["Permitted with limitations", "Special permit required", "Size restriction", "Additional conditions"]].any() else ("Yes" if row["Permitted"] else "No")), axis=1)
use_groups_zoning_districts_flags
# Out:
#      Use Group                                         Use Header  \
# 0            I                                        Agriculture
# 1            I                                          Open Uses
# 2            I                                          Open Uses
# 3            I                                          Open Uses
# 4            I                                          Open Uses
# ...        ...                                                ...
# 5119         X  Electrical Equipment, Appliance, and Component...
# 5120         X       Transportation Equipment Manufacturing (336)
# 5121         X  Furniture and Related Product Manufacturing (337)
# 5122         X                  Miscellaneous Manufacturing (339)
# 5123         X                  Miscellaneous Manufacturing (339)
#
#                                                Use Name Zoning District  \
# 0     Agricultural #uses#, including greenhouses, nu...              R1
# ...

# %%
use_groups_zoning_districts_flags.to_excel(
    OUTPUT_DIRECTORY / "use_groups_zoning_districts_flags_full2.xlsx", index=False
)

# %% [markdown]
# ## Join NAICS code descriptions

# %%
naics_codes = pd.read_csv(RESOURCES_DIRECTORY / "naics_codes.csv")
naics_codes
# Out:
#       Seq. No. 2022 NAICS US   Code  \
# 0            1                   11
# 1            2                  111
# 2            3                 1111
# 3            4                11111
# 4            5               111110
# ...        ...                  ...
# 2120      2121                 9281
# 2121      2122                92811
# 2122      2123               928110
# 2123      2124                92812
# 2124      2125               928120
#
#                                2022 NAICS US Title
# 0       Agriculture, Forestry, Fishing and Hunting
# 1                                  Crop Production
# 2                        Oilseed and Grain Farming
# 3                                  Soybean Farming
# 4                                  Soybean Farming
# ...                                            ...
# 2120  National Security and International Affairs
# 2121                            National Security
# 2122                            National Security
# ...

# %%
naics_codes.columns
# Out:
# Index(['Seq. No.', '2022 NAICS US   Code', '2022 NAICS US Title'], dtype='object')

# %%
naics_codes_cleaned = naics_codes.rename(columns={"2022 NAICS US   Code": "2022 NAICS US Code"}).drop(columns=["Seq. No."])

# %%
naics_codes_cleaned["2022 NAICS US Title"] = naics_codes_cleaned["2022 NAICS US Title"].map(
    lambda x: x.strip()
)

# %%
naics_codes_cleaned
# Out:
#      2022 NAICS US Code                          2022 NAICS US Title
# 0                    11   Agriculture, Forestry, Fishing and Hunting
# 1                   111                              Crop Production
# 2                  1111                    Oilseed and Grain Farming
# 3                 11111                              Soybean Farming
# 4                111110                              Soybean Farming
# ...                 ...                                          ...
# 2120               9281  National Security and International Affairs
# 2121              92811                            National Security
# 2122             928110                            National Security
# 2123              92812                        International Affairs
# 2124             928120                        International Affairs
#
# [2125 rows x 2 columns]

# %%
naics_codes_cleaned.to_csv(OUTPUT_DIRECTORY / "naics_codes_cleaned.csv", index=False)

# %% [markdown]
# ## Add ZR Links
# For additional conditions, size limitations, etc.

# %%
# Commercial District Use Regulations links:

# https://zr.planning.nyc.gov/article-iii/chapter-2#32-1[UG#][final_dig] (UGs 1-9)

# commercial_dist_reg_links = {}
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-11 - 6
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-111 (UG 1 - gen)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-112 (UG 1 - size)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-113 (UG 1 - addl cond)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-114 (UG 1 - open use)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-115 (UG 1 - special perm)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-116 (UG 1 - addl park)

# https://zr.planning.nyc.gov/article-iii/chapter-2#32-12 - 3
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-121 (UG 2 - gen)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-122 (UG 2 - limited appl)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-123 (UG 2 - addl cond)

# https://zr.planning.nyc.gov/article-iii/chapter-2#32-13 - 5
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-131 (UG 3 - gen)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-132 (UG 3 - size)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-133 (UG 3 - addl cond)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-134 (UG 3 - special perm)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-135 (UG 3 - addl park)

# https://zr.planning.nyc.gov/article-iii/chapter-2#32-14 - 5
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-141 (UG 4 - gen)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-142 (UG 4 - size)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-143 (UG 4 - addl cond)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-144 (UG 4 - open use)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-145 (UG 4 - special perm)

# https://zr.planning.nyc.gov/article-iii/chapter-2#32-15 - 6
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-151 (UG 5 - gen)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-152 (UG 5 - limited appl)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-153 (UG 5 - addl cond)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-154 (UG 5 - open use)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-155 (UG 5 - special perm)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-156 (UG 5 - addl park)

# https://zr.planning.nyc.gov/article-iii/chapter-2#32-16 - 6
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-161 (UG 6 - gen)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-162 (UG 6 - size)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-163 (UG 6 - addl cond)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-164 (UG 6 - open use)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-165 (UG 6 - special perm)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-166 (UG 6 - addl park)

# https://zr.planning.nyc.gov/article-iii/chapter-2#32-17 - 3
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-171 (UG 7 - gen)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-172 (UG 7 - limited appl)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-173 (UG 7 - addl cond)

# https://zr.planning.nyc.gov/article-iii/chapter-2#32-18 - 6
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-181 (UG 8 - gen)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-182 (UG 8 - size)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-183 (UG 8 - addl cond)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-184 (UG 8 - open use)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-185 (UG 8 - special perm)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-186 (UG 8 - addl park)

# https://zr.planning.nyc.gov/article-iii/chapter-2#32-19 - 7
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-191 (UG 9 - gen)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-192 (UG 9 - limited appl)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-193 (UG 9 - size)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-194 (UG 9 - addl cond)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-195 (UG 9 - open use)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-196 (UG 9 - special perm)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-197 (UG 9 - addl park)

# https://zr.planning.nyc.gov/article-iii/chapter-2#32-201 (UG 10 - gen)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-202 (UG 10 - size)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-203 (UG 10 - addl cond)
# https://zr.planning.nyc.gov/article-iii/chapter-2#32-204 (UG 10 - addl park)

# https://zr.planning.nyc.gov/article-iii/chapter-2#32-01 (Adult Establishments)

# Final digits vary across some UGs

# Final digit dict = {1:'general use allowances', 2:'uses subject to size limitations', 
                    # 3:'uses subject to additional conditions', 4:'uses subject to open use allowances',
                    # 5:'uses permitted by special permit', 6:'additional provisions for parking requirement category'}
        
# Final digit dict = {1:'general use allowances', 2:'uses permitted with limited applicability'
                    # 3:'uses subject to size limitations', 
                    # 4:'uses subject to additional conditions', 5:'uses subject to open use allowances',
                    # 6:'uses permitted by special permit', 7:'additional provisions for parking requirement category'}

# %%
# Residence District Use Regulations links:

# https://zr.planning.nyc.gov/article-ii/chapter-2#22-1[UG#][final_dig] (UGs 1-8 only)
# https://zr.planning.nyc.gov/article-ii/chapter-2#22-01 (Adult Establishments)

# %%
# Manufacturing District Use Regulations links:

# https://zr.planning.nyc.gov/article-iv/chapter-2#42-1[UG#][final_dig]

# https://zr.planning.nyc.gov/article-iv/chapter-2#42-11 - 5
#UG 1 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-111
#UG 1 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-112
#UG 1 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-113
#UG 1 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-114
#UG 1 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-115

# https://zr.planning.nyc.gov/article-iv/chapter-2#42-12 (ALL)

# https://zr.planning.nyc.gov/article-iv/chapter-2#42-13 - 4
#UG 3 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-131
#UG 3 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-132
#UG 3 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-133
#UG 3 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-134

# https://zr.planning.nyc.gov/article-iv/chapter-2#42-14 - 5
#UG 4 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-141
#UG 4 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-142
#UG 4 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-143
#UG 4 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-144
#UG 4 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-145

# https://zr.planning.nyc.gov/article-iv/chapter-2#42-15 - 4
#UG 5 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-151
#UG 5 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-152
#UG 5 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-153
#UG 5 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-154

# https://zr.planning.nyc.gov/article-iv/chapter-2#42-16 - 5
#UG 6 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-161
#UG 6 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-162
#UG 6 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-163
#UG 6 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-164
#UG 6 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-165

# https://zr.planning.nyc.gov/article-iv/chapter-2#42-17 (ALL)

# https://zr.planning.nyc.gov/article-iv/chapter-2#42-18 - 6
#UG 8 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-181
#UG 8 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-182
#UG 8 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-183
#UG 8 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-184
#UG 8 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-185
#UG 8 - x: https://zr.planning.nyc.gov/article-iv/chapter-2#42-186

# https://zr.planning.nyc.gov/article-iv/chapter-2#42-19 - 4

# UG 10
#UG 10 - gen: https://zr.planning.nyc.gov/article-iv/chapter-2#42-201
#UG 10 - addl cond: https://zr.planning.nyc.gov/article-iv/chapter-2#42-202

# https://zr.planning.nyc.gov/article-iv/chapter-2#42-01 (Adult Establishments)

# %%
#
